# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d3p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-100.npy")
d3p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-500.npy")
d3p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-1000.npy")
d3p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-2500.npy")
d3p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-5000.npy")
d3p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-10000.npy")
d3p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-20000.npy")
d3p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-3-n_points-30000.npy")

# %%
d4p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-100.npy")
d4p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-500.npy")
d4p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-1000.npy")
d4p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-2500.npy")
d4p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-5000.npy")
d4p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-10000.npy")
d4p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-20000.npy")
d4p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-4-n_points-30000.npy")

# %%
d5p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-100.npy")
d5p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-500.npy")
d5p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-1000.npy")
d5p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-2500.npy")
d5p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-5000.npy")
d5p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-10000.npy")
d5p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-20000.npy")
d5p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-5-n_points-30000.npy")

# %%
d6p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-100.npy")
d6p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-500.npy")
d6p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-1000.npy")
d6p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-2500.npy")
d6p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-5000.npy")
d6p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-10000.npy")
d6p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-20000.npy")
d6p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-6-n_points-30000.npy")

# %%
d7p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-100.npy")
d7p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-500.npy")
d7p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-1000.npy")
d7p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-2500.npy")
d7p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-5000.npy")
d7p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-10000.npy")
d7p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-20000.npy")
d7p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-7-n_points-30000.npy")

# %%
d8p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-100.npy")
d8p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-500.npy")
d8p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-1000.npy")
d8p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-2500.npy")
d8p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-5000.npy")
d8p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-10000.npy")
d8p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-20000.npy")
d8p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-8-n_points-30000.npy")

# %%
d9p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-100.npy")
d9p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-500.npy")
d9p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-1000.npy")
d9p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-2500.npy")
d9p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-5000.npy")
d9p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-10000.npy")
d9p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-20000.npy")
d9p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-9-n_points-30000.npy")

# %%
d10p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-100.npy")
d10p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-500.npy")
d10p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-1000.npy")
d10p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-2500.npy")
d10p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-5000.npy")
d10p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-10000.npy")
d10p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-20000.npy")
d10p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-10-n_points-30000.npy")

# %%
d11p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-100.npy")
d11p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-500.npy")
d11p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-1000.npy")
d11p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-2500.npy")
d11p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-5000.npy")
d11p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-10000.npy")
d11p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-20000.npy")
d11p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-11-n_points-30000.npy")

# %%
d12p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-100.npy")
d12p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-500.npy")
d12p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-1000.npy")
d12p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-2500.npy")
d12p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-5000.npy")
d12p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-10000.npy")
d12p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-20000.npy")
d12p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-12-n_points-30000.npy")

# %%
d13p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-100.npy")
d13p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-500.npy")
d13p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-1000.npy")
d13p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-2500.npy")
d13p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-5000.npy")
d13p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-10000.npy")
d13p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-20000.npy")
d13p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-13-n_points-30000.npy")

# %%
d14p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-100.npy")
d14p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-500.npy")
d14p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-1000.npy")
d14p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-2500.npy")
d14p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-5000.npy")
d14p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-10000.npy")
d14p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-20000.npy")
d14p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-14-n_points-30000.npy")

# %%
d15p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-100.npy")
d15p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-500.npy")
d15p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-1000.npy")
d15p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-2500.npy")
d15p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-5000.npy")
d15p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-10000.npy")
d15p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-20000.npy")
d15p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-15-n_points-30000.npy")

# %%
d16p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-100.npy")
d16p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-500.npy")
d16p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-1000.npy")
d16p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-2500.npy")
d16p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-5000.npy")
d16p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-10000.npy")
d16p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-20000.npy")
d16p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-16-n_points-30000.npy")

# %%
d17p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-100.npy")
d17p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-500.npy")
d17p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-1000.npy")
d17p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-2500.npy")
d17p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-5000.npy")
d17p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-10000.npy")
d17p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-20000.npy")
d17p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-17-n_points-30000.npy")

# %%
d18p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-100.npy")
d18p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-500.npy")
d18p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-1000.npy")
d18p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-2500.npy")
d18p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-5000.npy")
d18p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-10000.npy")
d18p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-20000.npy")
d18p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-18-n_points-30000.npy")

# %%
d19p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-100.npy")
d19p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-500.npy")
d19p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-1000.npy")
d19p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-2500.npy")
d19p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-5000.npy")
d19p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-10000.npy")
d19p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-20000.npy")
d19p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-19-n_points-30000.npy")

# %%
d20p100 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-100.npy")
d20p500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-500.npy")
d20p1000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-1000.npy")
d20p2500 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-2500.npy")
d20p5000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-5000.npy")
d20p10000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-10000.npy")
d20p20000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-20000.npy")
d20p30000 = np.load("./data/TripleHyperSpheres-tSNE-n_dims-20-n_points-30000.npy")

# %%
fig, axs = plt.subplots(8, 18, figsize=(36,16))
#plt.title("Triple hyperspheres embeddings with UMAP", fontsize=30)

axs[7,0].scatter(d3p100[:, 0], d3p100[:,1], c=d3p100[:,2], s=1)
axs[7,0].axis("off")
axs[7,1].scatter(d4p100[:, 0], d4p100[:,1], c=d4p100[:,2], s=1)
axs[7,1].axis("off")
axs[7,2].scatter(d5p100[:, 0], d5p100[:,1], c=d5p100[:,2], s=1)
axs[7,2].axis("off")
axs[7,3].scatter(d6p100[:, 0], d6p100[:,1], c=d6p100[:,2], s=1)
axs[7,3].axis("off")
axs[7,4].scatter(d7p100[:, 0], d7p100[:,1], c=d7p100[:,2], s=1)
axs[7,4].axis("off")
axs[7,5].scatter(d8p100[:, 0], d8p100[:,1], c=d8p100[:,2], s=1)
axs[7,5].axis("off")
axs[7,6].scatter(d9p100[:, 0], d9p100[:,1], c=d9p100[:,2], s=1)
axs[7,6].axis("off")
axs[7,7].scatter(d10p100[:, 0], d10p100[:,1], c=d10p100[:,2], s=1)
axs[7,7].axis("off")
axs[7,8].scatter(d11p100[:, 0], d11p100[:,1], c=d11p100[:,2], s=1)
axs[7,8].axis("off")
axs[7,9].scatter(d12p100[:, 0], d12p100[:,1], c=d12p100[:,2], s=1)
axs[7,9].axis("off")
axs[7,10].scatter(d13p100[:, 0], d13p100[:,1], c=d13p100[:,2], s=1)
axs[7,10].axis("off")
axs[7,11].scatter(d14p100[:, 0], d14p100[:,1], c=d14p100[:,2], s=1)
axs[7,11].axis("off")
axs[7,12].scatter(d15p100[:, 0], d15p100[:,1], c=d15p100[:,2], s=1)
axs[7,12].axis("off")
axs[7,13].scatter(d16p100[:, 0], d16p100[:,1], c=d16p100[:,2], s=1)
axs[7,13].axis("off")
axs[7,14].scatter(d17p100[:, 0], d17p100[:,1], c=d17p100[:,2], s=1)
axs[7,14].axis("off")
axs[7,15].scatter(d18p100[:, 0], d18p100[:,1], c=d18p100[:,2], s=1)
axs[7,15].axis("off")
axs[7,16].scatter(d19p100[:, 0], d19p100[:,1], c=d19p100[:,2], s=1)
axs[7,16].axis("off")
axs[7,17].scatter(d20p100[:, 0], d20p100[:,1], c=d20p100[:,2], s=1)
axs[7,17].axis("off")

axs[6,0].scatter(d3p500[:, 0], d3p500[:,1], c=d3p500[:,2], s=1)
axs[6,0].axis("off")
axs[6,1].scatter(d4p500[:, 0], d4p500[:,1], c=d4p500[:,2], s=1)
axs[6,1].axis("off")
axs[6,2].scatter(d5p500[:, 0], d5p500[:,1], c=d5p500[:,2], s=1)
axs[6,2].axis("off")
axs[6,3].scatter(d6p500[:, 0], d6p500[:,1], c=d6p500[:,2], s=1)
axs[6,3].axis("off")
axs[6,4].scatter(d7p500[:, 0], d7p500[:,1], c=d7p500[:,2], s=1)
axs[6,4].axis("off")
axs[6,5].scatter(d8p500[:, 0], d8p500[:,1], c=d8p500[:,2], s=1)
axs[6,5].axis("off")
axs[6,6].scatter(d9p500[:, 0], d9p500[:,1], c=d9p500[:,2], s=1)
axs[6,6].axis("off")
axs[6,7].scatter(d10p500[:, 0], d10p500[:,1], c=d10p500[:,2], s=1)
axs[6,7].axis("off")
axs[6,8].scatter(d11p500[:, 0], d11p500[:,1], c=d11p500[:,2], s=1)
axs[6,8].axis("off")
axs[6,9].scatter(d12p500[:, 0], d12p500[:,1], c=d12p500[:,2], s=1)
axs[6,9].axis("off")
axs[6,10].scatter(d13p500[:, 0], d13p500[:,1], c=d13p500[:,2], s=1)
axs[6,10].axis("off")
axs[6,11].scatter(d14p500[:, 0], d14p500[:,1], c=d14p500[:,2], s=1)
axs[6,11].axis("off")
axs[6,12].scatter(d15p500[:, 0], d15p500[:,1], c=d15p500[:,2], s=1)
axs[6,12].axis("off")
axs[6,13].scatter(d16p500[:, 0], d16p500[:,1], c=d16p500[:,2], s=1)
axs[6,13].axis("off")
axs[6,14].scatter(d17p500[:, 0], d17p500[:,1], c=d17p500[:,2], s=1)
axs[6,14].axis("off")
axs[6,15].scatter(d18p500[:, 0], d18p500[:,1], c=d18p500[:,2], s=1)
axs[6,15].axis("off")
axs[6,16].scatter(d19p500[:, 0], d19p500[:,1], c=d19p500[:,2], s=1)
axs[6,16].axis("off")
axs[6,17].scatter(d20p500[:, 0], d20p500[:,1], c=d20p500[:,2], s=1)
axs[6,17].axis("off")

axs[5,0].scatter(d3p1000[:, 0], d3p1000[:,1], c=d3p1000[:,2], s=1)
axs[5,0].axis("off")
axs[5,1].scatter(d4p1000[:, 0], d4p1000[:,1], c=d4p1000[:,2], s=1)
axs[5,1].axis("off")
axs[5,2].scatter(d5p1000[:, 0], d5p1000[:,1], c=d5p1000[:,2], s=1)
axs[5,2].axis("off")
axs[5,3].scatter(d6p1000[:, 0], d6p1000[:,1], c=d6p1000[:,2], s=1)
axs[5,3].axis("off")
axs[5,4].scatter(d7p1000[:, 0], d7p1000[:,1], c=d7p1000[:,2], s=1)
axs[5,4].axis("off")
axs[5,5].scatter(d8p1000[:, 0], d8p1000[:,1], c=d8p1000[:,2], s=1)
axs[5,5].axis("off")
axs[5,6].scatter(d9p1000[:, 0], d9p1000[:,1], c=d9p1000[:,2], s=1)
axs[5,6].axis("off")
axs[5,7].scatter(d10p1000[:, 0], d10p1000[:,1], c=d10p1000[:,2], s=1)
axs[5,7].axis("off")
axs[5,8].scatter(d11p1000[:, 0], d11p1000[:,1], c=d11p1000[:,2], s=1)
axs[5,8].axis("off")
axs[5,9].scatter(d12p1000[:, 0], d12p1000[:,1], c=d12p1000[:,2], s=1)
axs[5,9].axis("off")
axs[5,10].scatter(d13p1000[:, 0], d13p1000[:,1], c=d13p1000[:,2], s=1)
axs[5,10].axis("off")
axs[5,11].scatter(d14p1000[:, 0], d14p1000[:,1], c=d14p1000[:,2], s=1)
axs[5,11].axis("off")
axs[5,12].scatter(d15p1000[:, 0], d15p1000[:,1], c=d15p1000[:,2], s=1)
axs[5,12].axis("off")
axs[5,13].scatter(d16p1000[:, 0], d16p1000[:,1], c=d16p1000[:,2], s=1)
axs[5,13].axis("off")
axs[5,14].scatter(d17p1000[:, 0], d17p1000[:,1], c=d17p1000[:,2], s=1)
axs[5,14].axis("off")
axs[5,15].scatter(d18p1000[:, 0], d18p1000[:,1], c=d18p1000[:,2], s=1)
axs[5,15].axis("off")
axs[5,16].scatter(d19p1000[:, 0], d19p1000[:,1], c=d19p1000[:,2], s=1)
axs[5,16].axis("off")
axs[5,17].scatter(d20p1000[:, 0], d20p1000[:,1], c=d20p1000[:,2], s=1)
axs[5,17].axis("off")

axs[4,0].scatter(d3p2500[:, 0], d3p2500[:,1], c=d3p2500[:,2], s=1)
axs[4,0].axis("off")
axs[4,1].scatter(d4p2500[:, 0], d4p2500[:,1], c=d4p2500[:,2], s=1)
axs[4,1].axis("off")
axs[4,2].scatter(d5p2500[:, 0], d5p2500[:,1], c=d5p2500[:,2], s=1)
axs[4,2].axis("off")
axs[4,3].scatter(d6p2500[:, 0], d6p2500[:,1], c=d6p2500[:,2], s=1)
axs[4,3].axis("off")
axs[4,4].scatter(d7p2500[:, 0], d7p2500[:,1], c=d7p2500[:,2], s=1)
axs[4,4].axis("off")
axs[4,5].scatter(d8p2500[:, 0], d8p2500[:,1], c=d8p2500[:,2], s=1)
axs[4,5].axis("off")
axs[4,6].scatter(d9p2500[:, 0], d9p2500[:,1], c=d9p2500[:,2], s=1)
axs[4,6].axis("off")
axs[4,7].scatter(d10p2500[:, 0], d10p2500[:,1], c=d10p2500[:,2], s=1)
axs[4,7].axis("off")
axs[4,8].scatter(d11p2500[:, 0], d11p2500[:,1], c=d11p2500[:,2], s=1)
axs[4,8].axis("off")
axs[4,9].scatter(d12p2500[:, 0], d12p2500[:,1], c=d12p2500[:,2], s=1)
axs[4,9].axis("off")
axs[4,10].scatter(d13p2500[:, 0], d13p2500[:,1], c=d13p2500[:,2], s=1)
axs[4,10].axis("off")
axs[4,11].scatter(d14p2500[:, 0], d14p2500[:,1], c=d14p2500[:,2], s=1)
axs[4,11].axis("off")
axs[4,12].scatter(d15p2500[:, 0], d15p2500[:,1], c=d15p2500[:,2], s=1)
axs[4,12].axis("off")
axs[4,13].scatter(d16p2500[:, 0], d16p2500[:,1], c=d16p2500[:,2], s=1)
axs[4,13].axis("off")
axs[4,14].scatter(d17p2500[:, 0], d17p2500[:,1], c=d17p2500[:,2], s=1)
axs[4,14].axis("off")
axs[4,15].scatter(d18p2500[:, 0], d18p2500[:,1], c=d18p2500[:,2], s=1)
axs[4,15].axis("off")
axs[4,16].scatter(d19p2500[:, 0], d19p2500[:,1], c=d19p2500[:,2], s=1)
axs[4,16].axis("off")
axs[4,17].scatter(d20p2500[:, 0], d20p2500[:,1], c=d20p2500[:,2], s=1)
axs[4,17].axis("off")

axs[3,0].scatter(d3p5000[:, 0], d3p5000[:,1], c=d3p5000[:,2], s=1)
axs[3,0].axis("off")
axs[3,1].scatter(d4p5000[:, 0], d4p5000[:,1], c=d4p5000[:,2], s=1)
axs[3,1].axis("off")
axs[3,2].scatter(d5p5000[:, 0], d5p5000[:,1], c=d5p5000[:,2], s=1)
axs[3,2].axis("off")
axs[3,3].scatter(d6p5000[:, 0], d6p5000[:,1], c=d6p5000[:,2], s=1)
axs[3,3].axis("off")
axs[3,4].scatter(d7p5000[:, 0], d7p5000[:,1], c=d7p5000[:,2], s=1)
axs[3,4].axis("off")
axs[3,5].scatter(d8p5000[:, 0], d8p5000[:,1], c=d8p5000[:,2], s=1)
axs[3,5].axis("off")
axs[3,6].scatter(d9p5000[:, 0], d9p5000[:,1], c=d9p5000[:,2], s=1)
axs[3,6].axis("off")
axs[3,7].scatter(d10p5000[:, 0], d10p5000[:,1], c=d10p5000[:,2], s=1)
axs[3,7].axis("off")
axs[3,8].scatter(d11p5000[:, 0], d11p5000[:,1], c=d11p5000[:,2], s=1)
axs[3,8].axis("off")
axs[3,9].scatter(d12p5000[:, 0], d12p5000[:,1], c=d12p5000[:,2], s=1)
axs[3,9].axis("off")
axs[3,10].scatter(d13p5000[:, 0], d13p5000[:,1], c=d13p5000[:,2], s=1)
axs[3,10].axis("off")
axs[3,11].scatter(d14p5000[:, 0], d14p5000[:,1], c=d14p5000[:,2], s=1)
axs[3,11].axis("off")
axs[3,12].scatter(d15p5000[:, 0], d15p5000[:,1], c=d15p5000[:,2], s=1)
axs[3,12].axis("off")
axs[3,13].scatter(d16p5000[:, 0], d16p5000[:,1], c=d16p5000[:,2], s=1)
axs[3,13].axis("off")
axs[3,14].scatter(d17p5000[:, 0], d17p5000[:,1], c=d17p5000[:,2], s=1)
axs[3,14].axis("off")
axs[3,15].scatter(d18p5000[:, 0], d18p5000[:,1], c=d18p5000[:,2], s=1)
axs[3,15].axis("off")
axs[3,16].scatter(d19p5000[:, 0], d19p5000[:,1], c=d19p5000[:,2], s=1)
axs[3,16].axis("off")
axs[3,17].scatter(d20p5000[:, 0], d20p5000[:,1], c=d20p5000[:,2], s=1)
axs[3,17].axis("off")

axs[2,0].scatter(d3p10000[:, 0], d3p10000[:,1], c=d3p10000[:,2], s=1)
axs[2,0].axis("off")
axs[2,1].scatter(d4p10000[:, 0], d4p10000[:,1], c=d4p10000[:,2], s=1)
axs[2,1].axis("off")
axs[2,2].scatter(d5p10000[:, 0], d5p10000[:,1], c=d5p10000[:,2], s=1)
axs[2,2].axis("off")
axs[2,3].scatter(d6p10000[:, 0], d6p10000[:,1], c=d6p10000[:,2], s=1)
axs[2,3].axis("off")
axs[2,4].scatter(d7p10000[:, 0], d7p10000[:,1], c=d7p10000[:,2], s=1)
axs[2,4].axis("off")
axs[2,5].scatter(d8p10000[:, 0], d8p10000[:,1], c=d8p10000[:,2], s=1)
axs[2,5].axis("off")
axs[2,6].scatter(d9p10000[:, 0], d9p10000[:,1], c=d9p10000[:,2], s=1)
axs[2,6].axis("off")
axs[2,7].scatter(d10p10000[:, 0], d10p10000[:,1], c=d10p10000[:,2], s=1)
axs[2,7].axis("off")
axs[2,8].scatter(d11p10000[:, 0], d11p10000[:,1], c=d11p10000[:,2], s=1)
axs[2,8].axis("off")
axs[2,9].scatter(d12p10000[:, 0], d12p10000[:,1], c=d12p10000[:,2], s=1)
axs[2,9].axis("off")
axs[2,10].scatter(d13p10000[:, 0], d13p10000[:,1], c=d13p10000[:,2], s=1)
axs[2,10].axis("off")
axs[2,11].scatter(d14p10000[:, 0], d14p10000[:,1], c=d14p10000[:,2], s=1)
axs[2,11].axis("off")
axs[2,12].scatter(d15p10000[:, 0], d15p10000[:,1], c=d15p10000[:,2], s=1)
axs[2,12].axis("off")
axs[2,13].scatter(d16p10000[:, 0], d16p10000[:,1], c=d16p10000[:,2], s=1)
axs[2,13].axis("off")
axs[2,14].scatter(d17p10000[:, 0], d17p10000[:,1], c=d17p10000[:,2], s=1)
axs[2,14].axis("off")
axs[2,15].scatter(d18p10000[:, 0], d18p10000[:,1], c=d18p10000[:,2], s=1)
axs[2,15].axis("off")
axs[2,16].scatter(d19p10000[:, 0], d19p10000[:,1], c=d19p10000[:,2], s=1)
axs[2,16].axis("off")
axs[2,17].scatter(d20p10000[:, 0], d20p10000[:,1], c=d20p10000[:,2], s=1)
axs[2,17].axis("off")

axs[1,0].scatter(d3p20000[:, 0], d3p20000[:,1], c=d3p20000[:,2], s=1)
axs[1,0].axis("off")
axs[1,1].scatter(d4p20000[:, 0], d4p20000[:,1], c=d4p20000[:,2], s=1)
axs[1,1].axis("off")
axs[1,2].scatter(d5p20000[:, 0], d5p20000[:,1], c=d5p20000[:,2], s=1)
axs[1,2].axis("off")
axs[1,3].scatter(d6p20000[:, 0], d6p20000[:,1], c=d6p20000[:,2], s=1)
axs[1,3].axis("off")
axs[1,4].scatter(d7p20000[:, 0], d7p20000[:,1], c=d7p20000[:,2], s=1)
axs[1,4].axis("off")
axs[1,5].scatter(d8p20000[:, 0], d8p20000[:,1], c=d8p20000[:,2], s=1)
axs[1,5].axis("off")
axs[1,6].scatter(d9p20000[:, 0], d9p20000[:,1], c=d9p20000[:,2], s=1)
axs[1,6].axis("off")
axs[1,7].scatter(d10p20000[:, 0], d10p20000[:,1], c=d10p20000[:,2], s=1)
axs[1,7].axis("off")
axs[1,8].scatter(d11p20000[:, 0], d11p20000[:,1], c=d11p20000[:,2], s=1)
axs[1,8].axis("off")
axs[1,9].scatter(d12p20000[:, 0], d12p20000[:,1], c=d12p20000[:,2], s=1)
axs[1,9].axis("off")
axs[1,10].scatter(d13p20000[:, 0], d13p20000[:,1], c=d13p20000[:,2], s=1)
axs[1,10].axis("off")
axs[1,11].scatter(d14p20000[:, 0], d14p20000[:,1], c=d14p20000[:,2], s=1)
axs[1,11].axis("off")
axs[1,12].scatter(d15p20000[:, 0], d15p20000[:,1], c=d15p20000[:,2], s=1)
axs[1,12].axis("off")
axs[1,13].scatter(d16p20000[:, 0], d16p20000[:,1], c=d16p20000[:,2], s=1)
axs[1,13].axis("off")
axs[1,14].scatter(d17p20000[:, 0], d17p20000[:,1], c=d17p20000[:,2], s=1)
axs[1,14].axis("off")
axs[1,15].scatter(d18p20000[:, 0], d18p20000[:,1], c=d18p20000[:,2], s=1)
axs[1,15].axis("off")
axs[1,16].scatter(d19p20000[:, 0], d19p20000[:,1], c=d19p20000[:,2], s=1)
axs[1,16].axis("off")
axs[1,17].scatter(d20p20000[:, 0], d20p20000[:,1], c=d20p20000[:,2], s=1)
axs[1,17].axis("off")

axs[0,0].scatter(d3p30000[:, 0], d3p30000[:,1], c=d3p30000[:,2], s=1)
axs[0,0].axis("off")
axs[0,1].scatter(d4p30000[:, 0], d4p30000[:,1], c=d4p30000[:,2], s=1)
axs[0,1].axis("off")
axs[0,2].scatter(d5p30000[:, 0], d5p30000[:,1], c=d5p30000[:,2], s=1)
axs[0,2].axis("off")
axs[0,3].scatter(d6p30000[:, 0], d6p30000[:,1], c=d6p30000[:,2], s=1)
axs[0,3].axis("off")
axs[0,4].scatter(d7p30000[:, 0], d7p30000[:,1], c=d7p30000[:,2], s=1)
axs[0,4].axis("off")
axs[0,5].scatter(d8p30000[:, 0], d8p30000[:,1], c=d8p30000[:,2], s=1)
axs[0,5].axis("off")
axs[0,6].scatter(d9p30000[:, 0], d9p30000[:,1], c=d9p30000[:,2], s=1)
axs[0,6].axis("off")
axs[0,7].scatter(d10p30000[:, 0], d10p30000[:,1], c=d10p30000[:,2], s=1)
axs[0,7].axis("off")
axs[0,8].scatter(d11p30000[:, 0], d11p30000[:,1], c=d11p30000[:,2], s=1)
axs[0,8].axis("off")
axs[0,9].scatter(d12p30000[:, 0], d12p30000[:,1], c=d12p30000[:,2], s=1)
axs[0,9].axis("off")
axs[0,10].scatter(d13p30000[:, 0], d13p30000[:,1], c=d13p30000[:,2], s=1)
axs[0,10].axis("off")
axs[0,11].scatter(d14p30000[:, 0], d14p30000[:,1], c=d14p30000[:,2], s=1)
axs[0,11].axis("off")
axs[0,12].scatter(d15p30000[:, 0], d15p30000[:,1], c=d15p30000[:,2], s=1)
axs[0,12].axis("off")
axs[0,13].scatter(d16p30000[:, 0], d16p30000[:,1], c=d16p30000[:,2], s=1)
axs[0,13].axis("off")
axs[0,14].scatter(d17p30000[:, 0], d17p30000[:,1], c=d17p30000[:,2], s=1)
axs[0,14].axis("off")
axs[0,15].scatter(d18p30000[:, 0], d18p30000[:,1], c=d18p30000[:,2], s=1)
axs[0,15].axis("off")
axs[0,16].scatter(d19p30000[:, 0], d19p30000[:,1], c=d19p30000[:,2], s=1)
axs[0,16].axis("off")
axs[0,17].scatter(d20p30000[:, 0], d20p30000[:,1], c=d20p30000[:,2], s=1)
axs[0,17].axis("off")

fig.add_subplot(111, frame_on=False)
#plt.tick_params(labelcolor='black', top=False, bottom=True, left=True, right=False, labelbottom=True, labeltop=False, labelleft=True, labelright=False, grid_color="black")

plt.xlabel("Number of dimensions", fontsize=20)
plt.ylabel("Number of points per class", fontsize=20)

#plt.xticks(list(range(3,21)))
#plt.yticks([100, 500, 1000, 2500, 5000, 10000, 20000, 30000])

plt.subplots_adjust(wspace=.5, hspace=.5)

#plt.savefig("TripleHyperspheresUMAP.svg")
plt.savefig("TripleHyperspherestSNE.png")
